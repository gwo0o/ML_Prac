# %%
import requests
from bs4 import BeautifulSoup as bs
import json

# def input_data(title, content, url):
#     sql = "INSERT INTO test_db3 (title, content, url) VALUES (%s, %s, %s)"
#     val = (title, content, url)

#     mycursor.execute(sql, val)

#     mydb.commit()

# def get_title(title):

#     sql = f'SELECT * FROM test_db3 WHERE title = "{title}"'

#     mycursor.execute(sql)

#     myresult = mycursor.fetchall()
#     return len(myresult)터

# mydb = mysql.connector.connect(
#     host = 'localhost',
#     user = 'root',
#     password = '1234',
#     database = 'Grip_Folder'
# )

# mycursor = mydb.cursor()

res = requests.get('https://news.hada.io/new')
soup = bs(res.content, 'html.parser')

a_data = soup.find('a', id = 'tr1')
title = a_data.string

a_content = soup.find('a', class_ = 'c99 breakall')
content_page = a_content.attrs['href']

a_time = soup.find('div', class_ = 'topicinfo')


url = f'https://news.hada.io/{content_page}'
temp = soup.find('a', class_ = "c99 breakall")
content = temp.string

content = content.replace('\n', '')

params = {
    "post_type" : "post.link",
    "post_title" : title,
    "post_content" : content,
    "only_ming" : 0,
    "extras": {
        "order":["post.link"],
        "link": {
            "url":url,
        }
    }
}
url2 = 'https://newming-v2-api.staging.newming.io/v2/api/posts/%EA%B0%9C%EB%B0%9C%EC%9E%90'
headers = {'Authorization': 'bearer aeyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..iwJLPmSw2iSRwKS3b9DqjIVYDJygGyWrMtt-k_oS1EE',
           'Content-Type': 'application/json'}

response = requests.post(url2, data=json.dumps(params), headers=headers)


data = []
data.append(title)
data.append(content)
data.append(url)
a_time = str(a_time)
index = a_time.find('분전')

if index == -1:
    data.append(0)
else:
    index2 = a_time[index-2:index]
    index2 = int(index2)
    data.append(index2)

print(data)
# Out:
# ['트위터, 인증 마크에 월 $20를 부과하는걸 계획중', '- 지금의 월 $4.99 짜리 Twitter Blue 구독을 더 비싼 요금제로 변경하는 것   \r- 현재 인증된 사용자도 90일내에 구독하지 않으면 파란색 체크 ...', 'https://news.hada.io/topic?id=7708', 21]
